# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('2024.xlsx')
df.head()
# Out:
#    S No  Gender  Type of Occupation  Financial Condition  \
# 0     1       1                   5                    2
# 1     2       1                   5                    2
# 2     3       1                   5                    1
# 3     4       1                   5                    2
# 4     5       1                   5                    3
#
#    Occupational/Job Insecurities  Survival Anxiety  \
# 0                              2                 3
# 1                              2                 2
# 2                              4                 2
# 3                              4                 2
# 4                              1                 4
#
#    Family & Social Support System  \
# 0                               4
# 1                               3
# 2                               5
# 3                               4
# 4                               3
#
#    Future Employment Opportunitie/Long term Plans  Migration
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 9 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   S No                                            184 non-null    int64
#  1   Gender                                          184 non-null    int64
#  2   Type of Occupation                              184 non-null    int64
#  3   Financial Condition                             184 non-null    int64
#  4   Occupational/Job Insecurities                   184 non-null    int64
#  5   Survival Anxiety                                184 non-null    int64
#  6   Family & Social Support System                  184 non-null    int64
#  7   Future Employment Opportunitie/Long term Plans  184 non-null    int64
#  8   Migration                                       184 non-null    int64
# dtypes: int64(9)
# memory usage: 13.1 KB

# %%
df=df.drop(columns=['S No'],axis=1)

# %%
df.describe()
# Out:
#            Gender  Type of Occupation  Financial Condition  \
# count  184.000000          184.000000           184.000000
# mean     1.130435            2.983696             2.967391
# std      0.337700            1.580190             1.173022
# min      1.000000            1.000000             1.000000
# 25%      1.000000            1.000000             2.000000
# 50%      1.000000            3.000000             3.000000
# 75%      1.000000            4.000000             4.000000
# max      2.000000            5.000000             5.000000
#
#        Occupational/Job Insecurities  Survival Anxiety  \
# count                     184.000000        184.000000
# mean                        3.434783          3.635870
# std                         1.180945          1.067665
# min                         1.000000          1.000000
# 25%                         3.000000          3.000000
# 50%                         4.000000          4.000000
# ...

# %%
plt.hist(df['Gender'], bins=30, edgecolor='black')
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.hist(df['Type of Occupation'], bins=30, edgecolor='black')
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.hist(df['Financial Condition'], bins=30, edgecolor='black')
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
#Occupational/Job Insecurities
plt.hist(df['Occupational/Job Insecurities'], bins=30, edgecolor='black')
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
#Survival Anxiety
plt.hist(df['Survival Anxiety'], bins=30, edgecolor='black')
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
#Family & Social Support System
plt.hist(df['Family & Social Support System'], bins=30, edgecolor='black')
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
#Future Employment Opportunitie/Long term Plans
plt.hist(df['Future Employment Opportunitie/Long term Plans'], bins=30, edgecolor='black')
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
sns.pairplot(df, hue='Gender')
plt.show()

# %%
plt.figure(figsize=(10, 6))  # Adjust size if necessary
sns.boxplot(data=df)
plt.title('Boxplots for Each Column')
plt.xlabel('Columns')
plt.ylabel('Values')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
pip install --upgrade pyparsing
# Out:
# ...
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 2.3.1
#     Uninstalling pyparsing-2.3.1:
#       Successfully uninstalled pyparsing-2.3.1
# ...
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
pip install pyparsing==2.3.1
# Out:
# ...
#   Using cached pyparsing-2.3.1-py2.py3-none-any.whl.metadata (1.0 kB)Note: you may need to restart the kernel to use updated packages.
#
# Using cached pyparsing-2.3.1-py2.py3-none-any.whl (61 kB)
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.2
#     Uninstalling pyparsing-3.1.2:
#       Successfully uninstalled pyparsing-3.1.2
# ...
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pydot 2.0.0 requires pyparsing>=3, but you have pyparsing 2.3.1 which is incompatible.

# %%
pip install pydotplus==2.0.2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from IPython.display import Image
import graphviz
import os

# Separate features (X) and labels (y)
X = df.drop(columns=['Migration'])  # Adjust 'target_column' with your actual target column name
y = df['Migration']

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize Decision Tree Classifier
decision_tree = DecisionTreeClassifier()

# Train the model
decision_tree.fit(X_train, y_train)

# Make predictions
y_pred = decision_tree.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

export_graphviz(decision_tree, out_file='tree.dot', feature_names=X.columns, class_names=[str(c) for c in decision_tree.classes_], filled=True)

# Convert the DOT file to an image
os.system('dot -Tpng tree.dot -o tree.png')

# Display the image
Image(filename='tree.png')
# Out:
# Accuracy: 0.8928571428571429

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, roc_curve, roc_auc_score, matthews_corrcoef, cohen_kappa_score

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", conf_matrix)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(y_test, y_pred)
print("Precision:", precision)

# Calculate sensitivity (recall)
sensitivity = recall_score(y_test, y_pred)
print("Sensitivity (Recall):", sensitivity)

# Calculate specificity
specificity = conf_matrix[0,0] / (conf_matrix[0,0] + conf_matrix[0,1])
print("Specificity:", specificity)

# Calculate MCC (Matthews correlation coefficient)
mcc = matthews_corrcoef(y_test, y_pred)
print("MCC (Matthews correlation coefficient):", mcc)

# Calculate Kappa coefficient
kappa = cohen_kappa_score(y_test, y_pred)
print("Kappa coefficient:", kappa)

# Calculate F-score
f_score = f1_score(y_test, y_pred)
print("F-score:", f_score)

# Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)
print("AUC (Area Under Curve):", auc)

# Plot ROC curve
import matplotlib.pyplot as plt
plt.plot(fpr, tpr, label='ROC Curve (AUC = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], 'k--')  # Random guess line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
#  [[43  4]
#  [ 2  7]]
# Accuracy: 0.8928571428571429
# Precision: 0.6363636363636364
# Sensitivity (Recall): 0.7777777777777778
# Specificity: 0.9148936170212766
# MCC (Matthews correlation coefficient): 0.6403167124751593
# Kappa coefficient: 0.6355748373101953
# F-score: 0.7000000000000001
# AUC (Area Under Curve): 0.8463356973995272

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# Define your model
model = DecisionTreeClassifier()

# Define the hyperparameter grid
param_grid = {
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10]
}

# Create a GridSearchCV object
grid_search = GridSearchCV(model, param_grid, scoring='accuracy', cv=5)

# Fit the model to the training data
grid_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters: ", best_params)
# Out:
# Best Hyperparameters:  {'max_depth': 3, 'min_samples_split': 5}

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from IPython.display import Image
import graphviz
import os

# Initialize Decision Tree Classifier with max_depth and min_samples_split parameters
decision_tree = DecisionTreeClassifier(max_depth=3, min_samples_split=2)

# Train the model
decision_tree.fit(X_train, y_train)
y_pred = decision_tree.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

export_graphviz(decision_tree, out_file='tree.dot', feature_names=X.columns, class_names=[str(c) for c in decision_tree.classes_], filled=True)

# Convert the DOT file to an image
os.system('dot -Tpng tree.dot -o tree.png')

# Display the image
Image(filename='tree.png')
# Out:
# Accuracy: 0.9107142857142857

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, roc_curve, roc_auc_score, matthews_corrcoef, cohen_kappa_score

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", conf_matrix)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(y_test, y_pred)
print("Precision:", precision)

# Calculate sensitivity (recall)
sensitivity = recall_score(y_test, y_pred)
print("Sensitivity (Recall):", sensitivity)

# Calculate specificity
specificity = conf_matrix[0,0] / (conf_matrix[0,0] + conf_matrix[0,1])
print("Specificity:", specificity)

# Calculate MCC (Matthews correlation coefficient)
mcc = matthews_corrcoef(y_test, y_pred)
print("MCC (Matthews correlation coefficient):", mcc)

# Calculate Kappa coefficient
kappa = cohen_kappa_score(y_test, y_pred)
print("Kappa coefficient:", kappa)

# Calculate F-score
f_score = f1_score(y_test, y_pred)
print("F-score:", f_score)

# Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)
print("AUC (Area Under Curve):", auc)

# Plot ROC curve
import matplotlib.pyplot as plt
plt.plot(fpr, tpr, label='ROC Curve (AUC = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], 'k--')  # Random guess line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
#  [[47  0]
#  [ 5  4]]
# Accuracy: 0.9107142857142857
# Precision: 1.0
# Sensitivity (Recall): 0.4444444444444444
# Specificity: 1.0
# MCC (Matthews correlation coefficient): 0.633805492015809
# Kappa coefficient: 0.5731707317073171
# F-score: 0.6153846153846153
# AUC (Area Under Curve): 0.7222222222222222

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)
# Initialize Random Forest Classifier
random_forest = RandomForestClassifier()

# Train the model
random_forest.fit(X_train, y_train)

# Select one of the decision trees from the random forest
# For example, let's select the first tree
tree_to_visualize = random_forest.estimators_[0]

# Export the selected decision tree to a DOT file
export_graphviz(tree_to_visualize, out_file='random_forest_tree.dot', feature_names=X.columns, class_names=[str(c) for c in random_forest.classes_], filled=True)

# Convert the DOT file to an image
os.system('dot -Tpng random_forest_tree.dot -o random_forest_tree.png')

# Display the image
Image(filename='random_forest_tree.png')

# %%
from sklearn.metrics import confusion_matrix, matthews_corrcoef, cohen_kappa_score, accuracy_score, precision_score, recall_score, f1_score

# Make predictions
y_pred = random_forest.predict(X_test)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Calculate MCC (Matthews correlation coefficient)
mcc = matthews_corrcoef(y_test, y_pred)
print("MCC (Matthews correlation coefficient):", mcc)

# Calculate kappa
kappa = cohen_kappa_score(y_test, y_pred)
print("Kappa:", kappa)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(y_test, y_pred)
print("Precision:", precision)

# Calculate sensitivity (recall)
sensitivity = recall_score(y_test, y_pred)
print("Sensitivity (Recall):", sensitivity)

# Calculate specificity
# To calculate specificity, we need to define a function
def specificity_score(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    return tn / (tn + fp)

specificity = specificity_score(y_test, y_pred)
print("Specificity:", specificity)

# Calculate F1-score
f1 = f1_score(y_test, y_pred)
print("F1-score:", f1)
# Out:
# Confusion Matrix:
# [[63  2]
#  [ 3  6]]
# MCC (Matthews correlation coefficient): 0.6693419514856722
# Kappa: 0.6678635547576302
# Accuracy: 0.9324324324324325
# Precision: 0.75
# Sensitivity (Recall): 0.6666666666666666
# Specificity: 0.9692307692307692
# F1-score: 0.7058823529411765

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Calculate probabilities for class 1
y_prob = random_forest.predict_proba(X_test)[:, 1]

# Calculate the false positive rate (FPR) and true positive rate (TPR)
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Calculate the area under the ROC curve (AUC)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score, matthews_corrcoef, cohen_kappa_score

# Make predictions on validation set
y_pred = model.predict(X_test)

# Calculate confusion matrix
conf_matrix_val = confusion_matrix(Y_train, y_pred)
print("Confusion Matrix (Validation):\n", conf_matrix_val)

# Calculate accuracy on validation set
accuracy_val = accuracy_score(Y_val, y_val_pred)
print("Validation Accuracy:", accuracy_val)

# Calculate precision on validation set
precision_val = precision_score(Y_val, y_val_pred)
print("Validation Precision:", precision_val)

# Calculate sensitivity (recall) on validation set
sensitivity_val = recall_score(Y_val, y_val_pred)
print("Validation Sensitivity (Recall):", sensitivity_val)

# Calculate specificity on validation set
specificity_val = conf_matrix_val[0,0] / (conf_matrix_val[0,0] + conf_matrix_val[0,1])
print("Validation Specificity:", specificity_val)

# Calculate MCC (Matthews correlation coefficient) on validation set
mcc_val = matthews_corrcoef(Y_val, y_val_pred)
print("Validation MCC (Matthews correlation coefficient):", mcc_val)

# Calculate Kappa coefficient on validation set
kappa_val = cohen_kappa_score(Y_val, y_val_pred)
print("Validation Kappa coefficient:", kappa_val)

# Calculate F-score on validation set
f_score_val = f1_score(Y_val, y_val_pred)
print("Validation F-score:", f_score_val)

# Calculate ROC curve and AUC on validation set
fpr_val, tpr_val, thresholds_val = roc_curve(Y_val, y_val_pred)
auc_val = roc_auc_score(Y_val, y_val_pred)
print("Validation AUC (Area Under Curve):", auc_val)

# Plot ROC curve for validation set
plt.plot(fpr_val, tpr_val, label='ROC Curve (AUC = %0.2f)' % auc_val)
plt.plot([0, 1], [0, 1], 'k--')  # Random guess line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.title('Receiver Operating Characteristic (ROC) Curve - Validation Set')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# Define your model
model = DecisionTreeClassifier()

# Define the hyperparameter grid
param_grid = {
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10]
}

# Create a GridSearchCV object
grid_search = GridSearchCV(model, param_grid, scoring='accuracy', cv=5)

# Fit the model to the training data
grid_search.fit(X_train, Y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters: ", best_params)

# %%
# Initialize Decision Tree Classifier with max_depth and min_samples_split parameters
decision_tree = DecisionTreeClassifier(max_depth=7, min_samples_split=2)

# Train the model
decision_tree.fit(X_train, y_train)

export_graphviz(decision_tree, out_file='tree.dot', feature_names=X.columns, class_names=[str(c) for c in decision_tree.classes_], filled=True)

# Convert the DOT file to an image
os.system('dot -Tpng tree.dot -o tree.png')

# Display the image
Image(filename='tree.png')

# %%
from sklearn import metrics
X_train, X_val, Y_train, Y_val = train_test_split(X,y,test_size = 0.2)
print(X_train.shape, X_val.shape)
model =  DecisionTreeClassifier()
model.fit(X_train, y_train)
print('Training Accuracy : ', metrics.accuracy_score(y_train, model.predict(X_train))*100)
print('Validation Accuracy : ', metrics.accuracy_score(Y_val, model.predict(X_val))*100)
